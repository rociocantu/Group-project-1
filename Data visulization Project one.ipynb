# %% [markdown]
# ## Dataset Description
# > This credit card dataset shows data for different customers according to their education level, gender, income level, gender, education level, total transaction amount on their credit card, and how long these accounts are on the book. The data is about twenty columns; it shows the spending habits of these customers. That data answers questions, such as whether income affects credit card debt, what causes most credit card debt, is credit card debt is worse for those with higher income level or lower income, and if there is a correlation between income, education, and credit card debt.
# ---
# #### Columns
# 1.  CLIENTINUM:this is customer_id
# 2.  Attrition_flag: contains existing customer and attrited customer
# 3.  Customer_Age: contains customers of different ages.
# 4.  Gender: deals with whether the customers are male or female.
# 5.  Dependent_count: deals with the number of dependents per household.
# 6.  Eductaion_level: deals with the education level of customers whether they are in high school, graduate, uneducated,   college, post-graduate, doctorate or unknown status.
# 7.  Marital_Status: deals with the different customer status if they are married, single, divorced or unkown status.
# 8.  Income-Category: contains the different income levels for various customers.
# 9.  Card_Category: contains the various credit cards and their credit limit.
# 10. Months_on_books: contains how long the credit card balance stayed on the record of the bank.
# 11. Avg_Open_To_Buy: contains the average open credit cards that are used for buying.
# 12. Total_Trans_Amt: contains the total transaction amounts for customers that have credit cards.
# 13. Total_Trans_Ct: contains the total count for credit card transactions.

# %% [markdown]
# ### import the required libraries

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %% [markdown]
# ### load dataset

# %%
df_ori=pd.read_csv("credit_card.csv")

# %%
display(df_ori.head())
display(df_ori.tail())
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# ### shape

# %%
df_ori.shape
# Out:
# (10127, 23)

# %% [markdown]
# ### columns

# %%
df_ori.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# ### Dtypes

# %%
df_ori.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %% [markdown]
# ### Statistics

# %%
df_ori.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# # data cleaning

# %%
df_ori.isna().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %% [markdown]
# **there is no nan value in the dataset**

# %%
df_ori.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **there is no duplicated values**

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### The required columns

# %%
df_ori.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
required=['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender', 'Education_Level', 'Marital_Status',
       'Income_Category','Credit_Limit','Months_on_book','Avg_Open_To_Buy','Total_Trans_Amt','Total_Trans_Ct']

df_clean=df_ori[required]
#df_clean=df_clean.set_index("CLIENTNUM")
df_clean
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 0      768805383  Existing Customer            45      M     High School
# 1      818770008  Existing Customer            49      F        Graduate
# 2      713982108  Existing Customer            51      M        Graduate
# 3      769911858  Existing Customer            40      F     High School
# 4      709106358  Existing Customer            40      M      Uneducated
# ...          ...                ...           ...    ...             ...
# 10122  772366833  Existing Customer            50      M        Graduate
# 10123  710638233  Attrited Customer            41      M         Unknown
# 10124  716506083  Attrited Customer            44      F     High School
# 10125  717406983  Attrited Customer            30      M        Graduate
# 10126  714337233  Attrited Customer            43      F        Graduate
#
#       Marital_Status Income_Category  Credit_Limit  Months_on_book  \
# ...

# %% [markdown]
# ### Linear relationship between columns

# %%
x=df_clean['Total_Trans_Ct'].values 
y=df_clean['Total_Trans_Amt'].values
slope,intercept,r,p,se=st.linregress(x,y)
print("r value of linear regression is:",round(r,3))
plt.scatter(x,y)
plt.plot(x,slope*x+intercept,color="red")
plt.show()
# the linear regression is strong
# Out:
# r value of linear regression is: 0.807

# %%
df_clean.plot(x='Credit_Limit',y='Avg_Open_To_Buy',kind="scatter")
#perfect linear relationship
plt.show()

# %%
df_clean.plot(x='Customer_Age',y='Months_on_book',kind="scatter")
plt.show()
# the customer age is strictly related to how long the credit card was open
# explore that

# %%
df_clean["Attrition_Flag"].value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
df_clean["Attrition_Flag"].value_counts().plot(kind="bar")
plt.show()

# %%
df_clean["Attrition_Flag"].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.show()

# %%
x=df_clean["Attrition_Flag"].value_counts()
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,7))
ax[0].bar(x.index,x.values)
ax[1].pie(x.values, autopct="%.2f%%")
plt.show()

# %%
x=df_clean["Education_Level"].value_counts().index
y=df_clean["Education_Level"].value_counts().values
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,7))
bar_plot=ax[0].bar(x,y, color = ["green","red","purple","blue","cyan","orange","lightblue"],label=x)
ax[0].bar_label(bar_plot)
ax[0].set_xticks(ax[0].get_xticks(),labels=x,rotation =75)
ax[1].pie(y, autopct="%.2f%%",labels=x, explode=[0.1,0,0,0,0,0.2,0],shadow=True,radius=1.1)
ax[1].set_title("% of Degrees",bbox={"facecolor":"0.9","pad":10},y=1.1)
ax[0].axis("off")
ax[0].legend()
fig.tight_layout(pad=5)
plt.show()

# %%
x=df_clean["Marital_Status"].value_counts().index
y=df_clean["Marital_Status"].value_counts().values
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,7))
bar_plot=ax[0].bar(x,y, color = ["green","red","purple","blue"],label=x)
ax[0].bar_label(bar_plot)
ax[0].set_xticks(ax[0].get_xticks(),labels=x,rotation =75)
ax[1].pie(y, autopct="%.2f%%",labels=x, explode=[0.1,0,0,0],shadow=True,radius=1.1)
ax[1].set_title("Marital Status",bbox={"facecolor":"0.9","pad":10},y=1.1)
ax[0].axis("off")
ax[0].legend()
fig.tight_layout(pad=5)
plt.show()
# Be careful the list lenght equals the elements of the column
# df_clean.value_counts("column name") column name will check the unique item

# %%
x=df_clean["Gender"].value_counts().index
y=df_clean["Gender"].value_counts().values
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,7))
bar_plot=ax[0].bar(x,y, color = ["red","blue"],label=x)
ax[0].bar_label(bar_plot)
ax[0].set_xticks(ax[0].get_xticks(),labels=x,rotation =75)
ax[1].pie(y, autopct="%.2f%%",labels=x, explode=[0.1,0],shadow=True,radius=1.1)
ax[1].set_title("Gender",bbox={"facecolor":"0.9","pad":10},y=1.1)
ax[0].axis("off")
ax[0].legend()
fig.tight_layout(pad=5)
plt.show()

# %%
x=df_clean["Gender"].value_counts()
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,7))
ax[0].bar(x.index,x.values)
ax[1].pie(x.values, autopct="%.2f%%")
plt.show()

# %%
x=df_clean["Education_Level"].value_counts()
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,7))
ax[0].bar(x.index,x.values)
##ax[0].set_xticklabels(ax[0].get_xticks(),rotation =75)
ax[0].set_xticklabels(x.index,rotation =75)
ax[1].pie(x.values, autopct="%.2f%%")
plt.show()
# Out:
# C:\Users\manal\AppData\Local\Temp\ipykernel_24048\2907383512.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(x.index,rotation =75)

# %%
df_clean.plot(y="Total_Trans_Ct", kind="hist",bins=20,color="orange",edgecolor="blue",grid=True, 
              xlabel="Number of Transactions")
plt.show()

# %%
df_clean.plot(y="Customer_Age", kind="hist",bins=20,color="orange",edgecolor="blue",grid=True, 
              xlabel="Customer Age")
plt.show()

# %%
df_clean.plot(y="Months_on_book", kind="hist",bins=20,color="orange",edgecolor="blue",grid=True, 
              xlabel="Months_on_book")
plt.show()

# %% [markdown]
# ---

# %%
df_ana=df_clean.copy()

# %%
df_ana.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 0  768805383  Existing Customer            45      M     High School
# 1  818770008  Existing Customer            49      F        Graduate
# 2  713982108  Existing Customer            51      M        Graduate
# 3  769911858  Existing Customer            40      F     High School
# 4  709106358  Existing Customer            40      M      Uneducated
#
#   Marital_Status Income_Category  Credit_Limit  Months_on_book  \
# 0        Married     $60K - $80K       12691.0              39
# 1         Single  Less than $40K        8256.0              44
# 2        Married    $80K - $120K        3418.0              36
# 3        Unknown  Less than $40K        3313.0              34
# 4        Married     $60K - $80K        4716.0              21
#
#    Avg_Open_To_Buy  Total_Trans_Amt  Total_Trans_Ct
# 0          11914.0             1144              42
# 1           7392.0             1291              33
# ...

# %%
df_exist=df_ana[df_ana["Attrition_Flag"]=="Existing Customer"]
df_attr=df_ana[df_ana["Attrition_Flag"]!="Existing Customer"]
display(df_attr.head())
df_exist
# Out:
#     CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 21  708508758  Attrited Customer            62      F        Graduate
# 39  708300483  Attrited Customer            66      F       Doctorate
# 51  779471883  Attrited Customer            54      F        Graduate
# 54  714374133  Attrited Customer            56      M        Graduate
# 61  712030833  Attrited Customer            48      M        Graduate
#
#    Marital_Status Income_Category  Credit_Limit  Months_on_book  \
# 21        Married  Less than $40K        1438.3              49
# 39        Married         Unknown        7882.0              56
# 51        Married  Less than $40K        1438.3              40
# 54        Married         $120K +       15769.0              36
# 61        Married     $60K - $80K       34516.0              35
#
#     Avg_Open_To_Buy  Total_Trans_Amt  Total_Trans_Ct
# 21           1438.3              692              16
# ...

# %%
df_exist.groupby("Education_Level").count()
# Out:
#                  CLIENTNUM  Attrition_Flag  Customer_Age  Gender  \
# Education_Level
# College                859             859           859     859
# Doctorate              356             356           356     356
# Graduate              2641            2641          2641    2641
# High School           1707            1707          1707    1707
# Post-Graduate          424             424           424     424
# Uneducated            1250            1250          1250    1250
# Unknown               1263            1263          1263    1263
#
#                  Marital_Status  Income_Category  Credit_Limit  \
# Education_Level
# College                     859              859           859
# Doctorate                   356              356           356
# Graduate                   2641             2641          2641
# High School                1707             1707          1707
# Post-Graduate               424              424           424
# ...

# %%
df_attr.groupby("Education_Level").count()
# Out:
#                  CLIENTNUM  Attrition_Flag  Customer_Age  Gender  \
# Education_Level
# College                154             154           154     154
# Doctorate               95              95            95      95
# Graduate               487             487           487     487
# High School            306             306           306     306
# Post-Graduate           92              92            92      92
# Uneducated             237             237           237     237
# Unknown                256             256           256     256
#
#                  Marital_Status  Income_Category  Credit_Limit  \
# Education_Level
# College                     154              154           154
# Doctorate                    95               95            95
# Graduate                    487              487           487
# High School                 306              306           306
# Post-Graduate                92               92            92
# ...

# %%
df_percentage.rename(columns={"CLIENTNUM":"Proporation"},inplace=True)
df_percentage ["Total"]=num_attr+num_exist
df_percentage["Percentage"]=df_percentage["Proporation"].apply(myfun)
df_percentage
# Out:
#                  Proporation  Total Percentage
# Income_Category
# $120K +             0.173315    727     17.33%
# $40K - $60K         0.151397   1790     15.14%
# $60K - $80K         0.134807   1402     13.48%
# $80K - $120K        0.157655   1535     15.77%
# Less than $40K      0.171862   3561     17.19%
# Unknown             0.168165   1112     16.82%

# %%
num_attr=df_attr.groupby("Education_Level").count()["CLIENTNUM"]
num_exist=df_exist.groupby("Education_Level").count()["CLIENTNUM"]

# %%
df_percentage=(num_attr/((num_attr+num_exist))).to_frame()
df_percentage
# Out:
#                  CLIENTNUM
# Education_Level
# College           0.152024
# Doctorate         0.210643
# Graduate          0.155691
# High School       0.152012
# Post-Graduate     0.178295
# Uneducated        0.159381
# Unknown           0.168532

# %%
def myfun(x):
    temp=x*100
    temp=round(temp,2)
    temp=str(temp)+"%"
    return temp

# %%
myfun(0.152024)
# Out:
# '15.2%'

# %%
df_percentage.rename(columns={"CLIENTNUM":"Proporation"},inplace=True)
df_percentage ["Total"]=num_attr+num_exist
df_percentage["Percentage"]=df_percentage["Proporation"].apply(myfun)
df_percentage
# Out:
#                  Proporation  Total Percentage
# Education_Level
# College             0.152024   1013      15.2%
# Doctorate           0.210643    451     21.06%
# Graduate            0.155691   3128     15.57%
# High School         0.152012   2013      15.2%
# Post-Graduate       0.178295    516     17.83%
# Uneducated          0.159381   1487     15.94%
# Unknown             0.168532   1519     16.85%

# %%
fig,ax=plt.subplots(figsize=(15,9))
ax.bar(df_percentage["Total"].index,df_percentage["Total"].values,color="orange",edgecolor="blue")
ax1=ax.twinx()
ax1.plot(df_percentage["Proporation"].index,df_percentage["Proporation"].values,color="red", linestyle=":",marker="D")

# %%
num_attr=df_attr.groupby("Income_Category").count()["CLIENTNUM"]
num_exist=df_exist.groupby("Income_Category").count()["CLIENTNUM"]
df_percentage=(num_attr/((num_attr+num_exist))).to_frame()
df_percentage.rename(columns={"CLIENTNUM":"Proporation"},inplace=True)
df_percentage ["Total"]=num_attr+num_exist
df_percentage["Percentage"]=df_percentage["Proporation"].apply(myfun)
df_percentage
# Out:
#                  Proporation  Total Percentage
# Income_Category
# $120K +             0.173315    727     17.33%
# $40K - $60K         0.151397   1790     15.14%
# $60K - $80K         0.134807   1402     13.48%
# $80K - $120K        0.157655   1535     15.77%
# Less than $40K      0.171862   3561     17.19%
# Unknown             0.168165   1112     16.82%

# %%
fig,ax=plt.subplots(figsize=(15,9))
ax.bar(df_percentage["Total"].index,df_percentage["Total"].values,color="orange",edgecolor="blue")
ax1=ax.twinx()
ax1.plot(df_percentage["Proporation"].index,df_percentage["Proporation"].values,color="red", linestyle=":",marker="D")

# %%
my_columns="Marital_Status"



num_attr=df_attr.groupby(my_columns).count()["CLIENTNUM"]
num_exist=df_exist.groupby(my_columns).count()["CLIENTNUM"]
df_percentage=(num_attr/((num_attr+num_exist))).to_frame()
df_percentage.rename(columns={"CLIENTNUM":"Proporation"},inplace=True)
df_percentage ["Total"]=num_attr+num_exist
df_percentage["Percentage"]=df_percentage["Proporation"].apply(myfun)
df_percentage
fig,ax=plt.subplots(figsize=(15,9))
ax.bar(df_percentage["Total"].index,df_percentage["Total"].values,color="orange",edgecolor="blue")
ax1=ax.twinx()
ax1.plot(df_percentage["Proporation"].index,df_percentage["Proporation"].values,color="red", linestyle=":",marker="D")
